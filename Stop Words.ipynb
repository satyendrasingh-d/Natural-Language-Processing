# %%
# Perform stand

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'besides', 'whoever', 'herein', 'you', 'your', 'using', 'as', 'further', 'not', 'used', 'due', 'often', 'amongst', "n't", 'quite', 'last', 'while', 'therefore', 'then', 'forty', 'none', 'beforehand', 'formerly', 'nine', 'am', 'well', 'otherwise', '‘s', 'with', 'neither', 'yourself', 'during', 'else', 'between', 'take', 'below', 'me', 'beside', 'both', 'ourselves', 'enough', 'three', 'moreover', 'thus', 'wherein', 'regarding', '’d', 'show', 'ours', '’ve', 'whereby', 'become', 'too', 're', 'whose', 'thereupon', 'off', 'through', 'whither', 'unless', 'part', 'at', 'five', 'being', 'anything', 'throughout', 'that', '’s', 'always', 'after', 'go', 'less', 'per', 'empty', 'therein', 'until', 'without', 'became', 'could', 'keep', 'down', 'the', 'meanwhile', '’ll', 'will', 'other', 'i', 'cannot', 'above', 'nowhere', 'than', 'yours', 'twenty', 'namely', 'hereby', 'former', 'whatever', 'something', 'twelve', 'serious', 'either', 'each', 'most', 'how', 'eight', 'against', 'were', 'across', '‘re', 'n’t', 'although', 'really', 'done', 'if', 'though', 'much', 'several', 'rather', 'some', 'few', 'itself', 'indeed', 'would', 'themselves', '‘ve', 'from', 'here', 'also', 'we', 'who', 'fifteen', 'another', 'give', 'front', 'hence', 'myself', 'even', 'very', 'have', 'ever', 'now', 'whereafter', '‘m', 'towards', 'had', 'get', "'re", 'somewhere', 'us', 'has', 'any', 'such', 'or', 'her', 'two', 'bottom', 'say', 'an', 'their', 'ca', 'somehow', 'is', 'fifty', 'except', 'mostly', 'and', 'to', 'others', 'perhaps', 'there', 'toward', 'back', 'may', 'seem', 'out', 'call', "'m", 'hereafter', 'still', 'be', 'full', 'anywhere', 'becoming', 'elsewhere', 'afterwards', 'latter', 'whole', 'must', 'does', 'my', 'make', 'put', "'ll", 'four', 'a', 'again', 'hundred', 'beyond', 'hers', 'nor', 'of', 'someone', 'was', 'own', 'only', 'should', 'in', 'noone', 'behind', 'many', 'are', 'nobody', 'all', 'sometimes', '‘d', 'top', 'seeming', 'everyone', 'side', 'latterly', 'seems', 'ten', 'why', '’m', 'every', 'more', 'thereby', 'she', 'almost', 'these', 'one', 'been', 'move', 'no', 'this', 'hereupon', 'same', 'them', "'s", 'n‘t', 'nothing', 'please', 'however', 'so', 'into', 'those', 'about', 'did', 'himself', 'least', '‘ll', 'thereafter', 'upon', 'its', 'yet', 'for', 'our', 'seemed', 'which', 'amount', 'everywhere', 'nevertheless', 'within', 'first', 'what', 'anyway', 'becomes', 'by', 'mine', 'whether', 'together', 'since', '’re', "'ve", 'alone', 'over', 'anyone', 'whence', 'when', 'whereupon', 'can', 'onto', 'thru', 'anyhow', 'might', 'it', 'his', 'do', "'d", 'him', 'before', 'but', 'once', 'up', 'never', 'eleven', 'name', 'six', 'sometime', 'whenever', 'see', 'among', 'whom', 'wherever', 'via', 'made', 'already', 'along', 'yourselves', 'next', 'where', 'on', 'everything', 'they', 'he', 'just', 'under', 'thence', 'various', 'around', 'herself', 'whereas', 'doing', 'sixty', 'because', 'third'}

# %% [markdown]
# # To Add a Stop Word

# %%
nlp.Defaults.stop_words.add('btw')
nlp.vocab['btw'].is_stop = True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
# To remove a stop word

# %%
# Remove the word from the set of stop words
nlp.Defaults.stop_words.remove('beyond')
# Remove the stop words tag from the lexeme
nlp.vocab['beyond'].is_stop = False

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['beyound'].is_stop
# Out:
# False

# %% [markdown]
# # **Implement POS tagging on a text corpus using an NLP library (like NLTK or SpaCy). Analyze the grammatical structure of sentences using syntactic/dependency parsing.**

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = "Data science is a multidisciplinary field that combines mathematics, statistics, computer science, and domain expertise to extract actionable insights from vast amounts of raw data. It involves systematically collecting, cleaning, and analyzing structured and unstructured datasets to uncover hidden patterns and predict future trends. By leveraging advanced technologies like machine learning, artificial intelligence, and cloud computing, data science empowers organizations across sectors like healthcare and finance to make evidence-based strategic decisions"

# %%
doc=nlp(text)

# %% [markdown]
# #POS tagging

# %%
for token in doc:
    print(f"{token.text:15}  POS: {token.pos_:10}  TAG: {token.tag_:10}  DEP: {token.dep_}  Description: {spacy.explain(token.tag_)}")
# Out:
# Data             POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# science          POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# is               POS: AUX         TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# multidisciplinary  POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# field            POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# that             POS: PRON        TAG: WDT         DEP: nsubj  Description: wh-determiner
# combines         POS: VERB        TAG: VBZ         DEP: relcl  Description: verb, 3rd person singular present
# mathematics      POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# statistics       POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# computer         POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# science          POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# domain           POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# expertise        POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# extract          POS: VERB        TAG: VB          DEP: advcl  Description: verb, base form
# actionable       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# insights         POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# vast             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# amounts          POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# raw              POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# data             POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# It               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# involves         POS: VERB        TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# systematically   POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# collecting       POS: VERB        TAG: VBG         DEP: xcomp  Description: verb, gerund or present participle
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# cleaning         POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# analyzing        POS: VERB        TAG: VBG         DEP: conj  Description: verb, gerund or present participle
# structured       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# unstructured     POS: ADJ         TAG: JJ          DEP: conj  Description: adjective (English), other noun-modifier (Chinese)
# datasets         POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# uncover          POS: VERB        TAG: VB          DEP: xcomp  Description: verb, base form
# hidden           POS: VERB        TAG: VBN         DEP: amod  Description: verb, past participle
# patterns         POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# predict          POS: VERB        TAG: VBP         DEP: conj  Description: verb, non-3rd person singular present
# future           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# trends           POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# By               POS: ADP         TAG: IN          DEP: ROOT  Description: conjunction, subordinating or preposition
# leveraging       POS: VERB        TAG: VBG         DEP: pcomp  Description: verb, gerund or present participle
# advanced         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# technologies     POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# like             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# machine          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# learning         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# artificial       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# intelligence     POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# cloud            POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# computing        POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# data             POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
# science          POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# empowers         POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
# organizations    POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# across           POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# sectors          POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# like             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# healthcare       POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# finance          POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# make             POS: VERB        TAG: VB          DEP: advcl  Description: verb, base form
# evidence         POS: NOUN        TAG: NN          DEP: npadvmod  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# based            POS: VERB        TAG: VBN         DEP: amod  Description: verb, past participle
# strategic        POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# decisions        POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural

# %% [markdown]
# #Dependency Parsing

# %%
for token in doc:
    print(f"{token.text:12} <--{token.dep_:10}-- {token.head.text}")
# Out:
# Data         <--compound  -- science
# science      <--nsubj     -- is
# is           <--ROOT      -- is
# a            <--det       -- field
# multidisciplinary <--amod      -- field
# field        <--attr      -- is
# that         <--nsubj     -- combines
# combines     <--relcl     -- field
# mathematics  <--dobj      -- combines
# ,            <--punct     -- mathematics
# statistics   <--conj      -- mathematics
# ,            <--punct     -- statistics
# computer     <--compound  -- science
# science      <--conj      -- statistics
# ,            <--punct     -- science
# and          <--cc        -- science
# domain       <--compound  -- expertise
# expertise    <--conj      -- science
# to           <--aux       -- extract
# extract      <--advcl     -- combines
# actionable   <--amod      -- insights
# insights     <--dobj      -- extract
# from         <--prep      -- insights
# vast         <--amod      -- amounts
# amounts      <--pobj      -- from
# of           <--prep      -- amounts
# raw          <--amod      -- data
# data         <--pobj      -- of
# .            <--punct     -- is
# It           <--nsubj     -- involves
# involves     <--ROOT      -- involves
# systematically <--advmod    -- collecting
# collecting   <--xcomp     -- involves
# ,            <--punct     -- collecting
# cleaning     <--conj      -- collecting
# ,            <--punct     -- cleaning
# and          <--cc        -- cleaning
# analyzing    <--conj      -- cleaning
# structured   <--amod      -- datasets
# and          <--cc        -- structured
# unstructured <--conj      -- structured
# datasets     <--dobj      -- analyzing
# to           <--aux       -- uncover
# uncover      <--xcomp     -- analyzing
# hidden       <--amod      -- patterns
# patterns     <--dobj      -- uncover
# and          <--cc        -- involves
# predict      <--conj      -- involves
# future       <--amod      -- trends
# trends       <--dobj      -- predict
# .            <--punct     -- involves
# By           <--ROOT      -- By
# leveraging   <--pcomp     -- By
# advanced     <--amod      -- technologies
# technologies <--dobj      -- leveraging
# like         <--prep      -- technologies
# machine      <--compound  -- learning
# learning     <--pobj      -- like
# ,            <--punct     -- learning
# artificial   <--amod      -- intelligence
# intelligence <--conj      -- learning
# ,            <--punct     -- intelligence
# and          <--cc        -- intelligence
# cloud        <--compound  -- computing
# computing    <--conj      -- intelligence
# ,            <--punct     -- learning
# data         <--compound  -- science
# science      <--nsubj     -- empowers
# empowers     <--compound  -- organizations
# organizations <--conj      -- learning
# across       <--prep      -- technologies
# sectors      <--pobj      -- across
# like         <--prep      -- sectors
# healthcare   <--pobj      -- like
# and          <--cc        -- healthcare
# finance      <--conj      -- healthcare
# to           <--aux       -- make
# make         <--advcl     -- leveraging
# evidence     <--npadvmod  -- based
# -            <--punct     -- based
# based        <--amod      -- decisions
# strategic    <--amod      -- decisions
# decisions    <--dobj      -- make

# %% [markdown]
# #Sentence wise grammar parsing

# %%
for sent in doc.sents:
    print("Sentence:", sent.text)
    for token in sent:
        print(f"  {token.text:15} {token.pos_:10} {token.dep_:10} --> {token.head.text}")
    print()
# Out:
# Sentence: Data science is a multidisciplinary field that combines mathematics, statistics, computer science, and domain expertise to extract actionable insights from vast amounts of raw data.
#   Data            NOUN       compound   --> science
#   science         NOUN       nsubj      --> is
#   is              AUX        ROOT       --> is
#   a               DET        det        --> field
#   multidisciplinary ADJ        amod       --> field
#   field           NOUN       attr       --> is
#   that            PRON       nsubj      --> combines
#   combines        VERB       relcl      --> field
#   mathematics     NOUN       dobj       --> combines
#   ,               PUNCT      punct      --> mathematics
#   statistics      NOUN       conj       --> mathematics
#   ,               PUNCT      punct      --> statistics
#   computer        NOUN       compound   --> science
#   science         NOUN       conj       --> statistics
#   ,               PUNCT      punct      --> science
#   and             CCONJ      cc         --> science
#   domain          NOUN       compound   --> expertise
#   expertise       NOUN       conj       --> science
#   to              PART       aux        --> extract
#   extract         VERB       advcl      --> combines
#   actionable      ADJ        amod       --> insights
#   insights        NOUN       dobj       --> extract
#   from            ADP        prep       --> insights
#   vast            ADJ        amod       --> amounts
#   amounts         NOUN       pobj       --> from
#   of              ADP        prep       --> amounts
#   raw             ADJ        amod       --> data
#   data            NOUN       pobj       --> of
#   .               PUNCT      punct      --> is
#
# Sentence: It involves systematically collecting, cleaning, and analyzing structured and unstructured datasets to uncover hidden patterns and predict future trends.
#   It              PRON       nsubj      --> involves
#   involves        VERB       ROOT       --> involves
#   systematically  ADV        advmod     --> collecting
#   collecting      VERB       xcomp      --> involves
#   ,               PUNCT      punct      --> collecting
#   cleaning        NOUN       conj       --> collecting
#   ,               PUNCT      punct      --> cleaning
#   and             CCONJ      cc         --> cleaning
#   analyzing       VERB       conj       --> cleaning
#   structured      ADJ        amod       --> datasets
#   and             CCONJ      cc         --> structured
#   unstructured    ADJ        conj       --> structured
#   datasets        NOUN       dobj       --> analyzing
#   to              PART       aux        --> uncover
#   uncover         VERB       xcomp      --> analyzing
#   hidden          VERB       amod       --> patterns
#   patterns        NOUN       dobj       --> uncover
#   and             CCONJ      cc         --> involves
#   predict         VERB       conj       --> involves
#   future          ADJ        amod       --> trends
#   trends          NOUN       dobj       --> predict
#   .               PUNCT      punct      --> involves
#
# Sentence: By leveraging advanced technologies like machine learning, artificial intelligence, and cloud computing, data science empowers organizations across sectors like healthcare and finance to make evidence-based strategic decisions
#   By              ADP        ROOT       --> By
#   leveraging      VERB       pcomp      --> By
#   advanced        ADJ        amod       --> technologies
#   technologies    NOUN       dobj       --> leveraging
#   like            ADP        prep       --> technologies
#   machine         NOUN       compound   --> learning
#   learning        NOUN       pobj       --> like
#   ,               PUNCT      punct      --> learning
#   artificial      ADJ        amod       --> intelligence
#   intelligence    NOUN       conj       --> learning
#   ,               PUNCT      punct      --> intelligence
#   and             CCONJ      cc         --> intelligence
#   cloud           NOUN       compound   --> computing
#   computing       NOUN       conj       --> intelligence
#   ,               PUNCT      punct      --> learning
#   data            NOUN       compound   --> science
#   science         NOUN       nsubj      --> empowers
#   empowers        NOUN       compound   --> organizations
#   organizations   NOUN       conj       --> learning
#   across          ADP        prep       --> technologies
#   sectors         NOUN       pobj       --> across
#   like            ADP        prep       --> sectors
#   healthcare      NOUN       pobj       --> like
#   and             CCONJ      cc         --> healthcare
#   finance         NOUN       conj       --> healthcare
#   to              PART       aux        --> make
#   make            VERB       advcl      --> leveraging
#   evidence        NOUN       npadvmod   --> based
#   -               PUNCT      punct      --> based
#   based           VERB       amod       --> decisions
#   strategic       ADJ        amod       --> decisions
#   decisions       NOUN       dobj       --> make

# %% [markdown]
# #Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9253493d05f64bdbb866efccda4ab7d9-0" class="displacy" width="30325" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Data</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">science</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">interdisciplinary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">academic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">field[1]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">uses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">statistics,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">scientific</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">computing,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">scientific</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">methods,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">processing,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">scientific</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">visualization,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">algorithms</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">systems</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">extract</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">extrapolate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">knowledge</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">potentially</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">noisy,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">structured,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor
